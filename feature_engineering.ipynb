# %%
import seaborn as sns
from imblearn.over_sampling import RandomOverSampler

from src.utils import deserialize_data, serialize_data

# %%
X_train_prep = deserialize_data("data/processed/X_train_prep.pkl")
y_train_prep = deserialize_data("data/processed/y_train_prep.pkl")

# %%
ros = RandomOverSampler()

# %%
# %matplotlib inline

sns.countplot(data=y_train_prep.to_frame(), x="loan_status", hue="loan_status")
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
X_train_ros, y_train_ros = ros.fit_resample(X_train_prep, y_train_prep)
# Out:
# /Users/rudi/Documents/pacmann/ML API/machine-learning-process/.venv/lib/python3.9/site-packages/sklearn/base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# /Users/rudi/Documents/pacmann/ML API/machine-learning-process/.venv/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
sns.countplot(data=y_train_ros.to_frame(), x="loan_status", hue="loan_status")
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
serialize_data(X_train_ros, "data/processed/X_train_ros.pkl")
serialize_data(y_train_ros, "data/processed/y_train_prep.pkl")
